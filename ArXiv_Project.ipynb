# %%
# !pip install arxiv
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 1.6 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=04b99fa1da4278365ea27ab8e3474fc054fe084a6112b75cc75e399039d7026d
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# ...

# %%
import arxiv
import pandas as pd

# %%
# Query to fetch AI-Related Papper
query = "AI OR Artificial Intelligent OR Machine Learning"
search = arxiv.Search(query=query, max_results=10, sort_by=arxiv.SortCriterion.SubmittedDate)

# Fetch papper
papper = []
for result in search.results():
  papper.append({
      "published": result.published,
      "title": result.title,
      "abstract": result.summary,
      "categories": result.categories
  })

# Convert to DataFrame
df = pd.DataFrame(papper)

pd.set_option("display.max_colwidth", None)
df.head()
# Out:
# /tmp/ipython-input-3108265767.py:7: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():
#                   published  \
# 0 2025-11-04 18:59:09+00:00
# 1 2025-11-04 18:58:47+00:00
# 2 2025-11-04 18:58:35+00:00
# 3 2025-11-04 18:58:20+00:00
# 4 2025-11-04 18:58:03+00:00
#
#                                                                                           title  \
# 0  Agent-Omni: Test-Time Multimodal Reasoning via Model Coordination for Understanding Anything
# 1                       In Good GRACEs: Principled Teacher Selection for Knowledge Distillation
# 2                      TWIST2: Scalable, Portable, and Holistic Humanoid Data Collection System
# 3                                   GeoCrossBench: Cross-Band Generalization for Remote Sensing
# 4             Densemarks: Learning Canonical Embeddings for Human Heads Images via Point Tracks
#
# ...

# %%
from transformers import pipeline
# Example abstract from API
abstract = df['abstract'][0]

summarizer = pipeline("summarization", model= "facebook/bart-large-cnn")

# Summarization
summarization_result = summarizer(abstract)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
summarization_result[0]['summary_text']
# Out:
# 'Multimodal large language models (MLLMs) have shown strong capabilities but are limited to fixed modality pairs. Building fully omni-capable models that can integratetext, images, audio, and video remains impractical and lacks robust reasoning support. We propose an Agent-Omni framework that coordinates existing foundation models through a master-agent system.'
